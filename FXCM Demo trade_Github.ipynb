# %%
import fxcmpy
# %matplotlib inline
fxcmpy.__version__
con = fxcmpy.fxcmpy(config_file='fxcm.cfg', server='demo')

print(con.get_instruments())
# Out:
# ['EUR/USD', 'USD/JPY', 'GBP/USD', 'USD/CHF', 'EUR/CHF', 'AUD/USD', 'USD/CAD', 'NZD/USD', 'EUR/GBP', 'EUR/JPY', 'GBP/JPY', 'CHF/JPY', 'GBP/CHF', 'EUR/AUD', 'EUR/CAD', 'AUD/CAD', 'AUD/JPY', 'CAD/JPY', 'NZD/JPY', 'GBP/CAD', 'GBP/NZD', 'GBP/AUD', 'AUD/NZD', 'USD/SEK', 'EUR/SEK', 'EUR/NOK', 'USD/NOK', 'USD/MXN', 'AUD/CHF', 'EUR/NZD', 'USD/ZAR', 'USD/HKD', 'ZAR/JPY', 'USD/TRY', 'EUR/TRY', 'NZD/CHF', 'CAD/CHF', 'NZD/CAD', 'TRY/JPY', 'USD/CNH', 'AUS200', 'ESP35', 'FRA40', 'GER30', 'HKG33', 'JPN225', 'NAS100', 'SPX500', 'UK100', 'US30', 'Copper', 'CHN50', 'EUSTX50', 'USDOLLAR', 'US2000', 'USOil', 'UKOil', 'SOYF', 'NGAS', 'WHEATF', 'CORNF', 'Bund', 'XAU/USD', 'XAG/USD', 'EMBasket', 'JPYBasket', 'BTC/USD', 'BCH/USD', 'ETH/USD', 'LTC/USD', 'XRP/USD', 'CryptoMajor', 'ESPORTS', 'BIOTECH', 'CANNABIS', 'FAANG', 'CHN.TECH', 'CHN.ECOMM', 'USEquities']

# %%
#Before you get live data, you have to Subscribe the market
con.subscribe_market_data('EUR/USD')
con.subscribe_market_data('USD/JPY')
con.subscribe_market_data('GBP/USD')
con.subscribe_market_data('USD/CHF')
con.subscribe_market_data('EUR/CHF')

# %%
con.get_subscribed_symbols()
# Out:
# ['EUR/USD', 'USD/JPY', 'GBP/USD', 'USD/CHF', 'EUR/CHF']

# %%
con.unsubscribe_market_data('USD/CHF')

# %%
con.get_subscribed_symbols()
# Out:
# ['EUR/USD', 'USD/JPY', 'GBP/USD', 'EUR/CHF']

# %%
instruments = con.get_instruments()
print(instruments[:5])
# Out:
# ['EUR/USD', 'USD/JPY', 'GBP/USD', 'USD/CHF', 'EUR/CHF']

# %%
data = con.get_candles('EUR/USD', period='m1', number=250)
data.head()
# Out:
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2020-02-13 06:46:00  1.08696   1.08699  1.08699  1.08694  1.08708   1.08710
# 2020-02-13 06:47:00  1.08699   1.08695  1.08699  1.08694  1.08710   1.08707
# 2020-02-13 06:48:00  1.08695   1.08699  1.08701  1.08694  1.08707   1.08712
# 2020-02-13 06:49:00  1.08700   1.08701  1.08701  1.08700  1.08712   1.08713
# 2020-02-13 06:50:00  1.08701   1.08700  1.08701  1.08700  1.08713   1.08713
#
#                      askhigh   asklow  tickqty
# date
# 2020-02-13 06:46:00  1.08712  1.08707       46
# 2020-02-13 06:47:00  1.08710  1.08706       37
# 2020-02-13 06:48:00  1.08713  1.08707       26
# 2020-02-13 06:49:00  1.08713  1.08712       10
# 2020-02-13 06:50:00  1.08713  1.08712       13

# %%
#fetch only the last available quotes
con.get_last_price('EUR/USD')
# Out:
# Bid     1.08704
# Ask     1.08716
# High    1.08894
# Low     1.08647
# Name: 2020-02-13 11:21:55.871000, dtype: float64

# %%
#After the subscription, fxcm.py collects the data in a pandas DataFrame. The con.get_prices() method returns that DataFrame object.
con.get_prices('EUR/USD')
# Out:
#                              Bid      Ask     High      Low
# 2020-02-13 10:51:24.364  1.08799  1.08811  1.08894  1.08647
# 2020-02-13 10:51:37.031  1.08797  1.08809  1.08894  1.08647
# 2020-02-13 10:51:37.737  1.08797  1.08808  1.08894  1.08647
# 2020-02-13 10:51:43.371  1.08797  1.08809  1.08894  1.08647
# 2020-02-13 10:51:44.466  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:44.767  1.08796  1.08807  1.08894  1.08647
# 2020-02-13 10:51:49.792  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:50.389  1.08796  1.08807  1.08894  1.08647
# 2020-02-13 10:51:52.191  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:52.336  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:53.072  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:53.593  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:54.674  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:54.899  1.08796  1.08808  1.08894  1.08647
# 2020-02-13 10:51:55.263  1.08796  1.08808  1.08894  1.08647
# ...

# %%
order = con.open_trade(symbol='USD/JPY', is_buy=True,
                       rate=105, is_in_pips=False,
                       amount='2000', time_in_force='GTC',
                       order_type='AtMarket', limit=120)

# %%
con.get_open_positions().T
# Out:
#                             0               1               2
# t                           1               1               1
# ratePrecision               3               3               3
# tradeId             210392444       210392457       210392478
# accountName          03346465        03346465        03346465
# accountId             3346465         3346465         3346465
# roll                        0               0               0
# com                         0               0               0
# open                  109.303         109.303         109.303
# valueDate
# grossPL              -558.393        -558.393        -1116.79
# close                 109.242         109.242         109.242
# visiblePL                -6.1            -6.1            -6.1
# isDisabled              False           False           False
# currency              USD/JPY         USD/JPY         USD/JPY
# isBuy                    True            True            True
# ...

# %%
con.close_trade(trade_id=210367903, amount=1)

# %%
##Start RESET API
to_show = ['tradeId', 'amountK','currency','grossPL','isBuy']
lags = 3
model = svm.SVC(C=100, probability=True)

# %%
import pandas as pd
def print_data(data, dataframe):
    print('%3d | %s | %s, %s, %s, %s, %s'
          % (len(dataframe), data['Symbol'],
             pd.to_datetime(int(data['Updated']), unit='ms'),
             data['Rates'][0], data['Rates'][1], data['Rates'][2],
             data['Rates'][3]))


con.subscribe_market_data('EUR/USD', (print_data,))
# Out:
# 1374 | EUR/USD | 2020-02-13 13:36:07.516000, 1.08575, 1.08585, 1.0889399999999998, 1.08525
# 1375 | EUR/USD | 2020-02-13 13:36:08.538000, 1.08576, 1.08585, 1.0889399999999998, 1.08525
# 1376 | EUR/USD | 2020-02-13 13:36:08.892000, 1.0857400000000001, 1.08585, 1.0889399999999998, 1.08525
# 1377 | EUR/USD | 2020-02-13 13:36:09.343000, 1.08575, 1.08585, 1.0889399999999998, 1.08525
# 1378 | EUR/USD | 2020-02-13 13:36:11.243000, 1.08575, 1.0858599999999998, 1.0889399999999998, 1.08525
# 1379 | EUR/USD | 2020-02-13 13:36:12.130000, 1.08578, 1.0858899999999998, 1.0889399999999998, 1.08525
# 1380 | EUR/USD | 2020-02-13 13:36:12.907000, 1.08579, 1.0858899999999998, 1.0889399999999998, 1.08525
# 1381 | EUR/USD | 2020-02-13 13:36:13.416000, 1.08578, 1.0858899999999998, 1.0889399999999998, 1.08525
# 1382 | EUR/USD | 2020-02-13 13:36:14.121000, 1.08579, 1.0858899999999998, 1.0889399999999998, 1.08525
# ...

# %%
con.get_offers(kind='dataframe')
# Out:
#             buy  buyTradable  currency  defaultSortOrder      emr  \
# 0       1.08560         True   EUR/USD               100    3.250
# 1     109.74500         True   USD/JPY               950    2.500
# 2       1.30368         True   GBP/USD               250    3.750
# 3       0.97894         True   USD/CHF              1250    5.000
# 4       1.06272         True   EUR/CHF              1450    6.500
# 5       0.67345         True   AUD/USD              1350    2.000
# 6       1.32545         True   USD/CAD              1750    2.500
# 7       0.64539         True   NZD/USD              1650    2.000
# 8       0.83283         True   EUR/GBP              1550    3.250
# 9     119.13600         True   EUR/JPY               850    3.250
# 10    143.07000         True   GBP/JPY              1050    3.750
# 11      1.61221         True   EUR/AUD              1400    3.250
# 12      1.43886         True   EUR/CAD              1500    3.250
# ...
